# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
3 >1
# Out:
# True

# %%
10 == 10
# Out:
# True

# %%
10 != 5
# Out:
# True

# %%
'Python' == 'Python'
# Out:
# True

# %%
'Python' == 'python'
# Out:
# False

# %%
'Python' != 'python'
# Out:
# True

# %%
10> 20
# Out:
# False

# %%
10 < 20
# Out:
# True

# %%
10 >= 10
# Out:
# True

# %%
10 <= 10
# Out:
# True

# %%
1 == 1.0
# Out:
# True

# %%
1 is 1.0
# Out:
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-14-2ebf4c947f31>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   1 is 1.0
# False

# %%
1 is not 1.0
# Out:
# <>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <ipython-input-15-7a2cea8bf2ec>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   1 is not 1.0
# True

# %%
id(1)
# Out:
# 94126325079360

# %%
id(1.0)
# Out:
# 140119814590000

# %%
### is 는 객체 비교

# %%
a = -5
a is -5
id(a)
# Out:
# <>:2: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:2: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-20-f1dac319fb8b>:2: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   a is -5
# 94126325079168

# %%
a = -6
a is -6
id(a)
# Out:
# <>:2: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:2: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-21-3cff12770ee0>:2: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   a is -6
# 140119814588528

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
False and False
# Out:
# False

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
not False
# Out:
# True

# %%
not True and False or not False
# Out:
# True

# %%
not True and False or not False
# Out:
# True

# %%
False and False or True
# Out:
# True

# %%
False or True
# Out:
# True

# %%
((not True) and False) or (not False)
# Out:
# True

# %%
10 == 10 and 10 != 5
# Out:
# True

# %%
10>5  or 10<3
# Out:
# True

# %%
not 10> 5
# Out:
# False

# %%
not 1 is 1.0
# Out:
# <>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <ipython-input-41-b4bf5bb1d071>:1: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   not 1 is 1.0
# True

# %%
bool(1)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(15)
# Out:
# True

# %%
bool('False')
# Out:
# True

# %%
print(False and True)
print(False and False)
# Out:
# False
# False

# %%
print(True or True)
print(True or False)
# Out:
# True
# True

# %%
True and 'Python'
# Out:
# 'Python'

# %%
'Python' and True
# Out:
# True

# %%
'Python' and False
# Out:
# False

# %%
False and 'Python'
# Out:
# False

# %%
0 and 'Python'
# Out:
# 0

# %% [markdown]
# ### 8.2.1
