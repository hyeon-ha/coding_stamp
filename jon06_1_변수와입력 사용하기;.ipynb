# %%
x = 10

# %%
y = 'Hello, world!'

# %%
x
# Out:
# 10

# %%
y
# Out:
# 'Hello, world!'

# %%
type(x)
# Out:
# int

# %%
type(y)
# Out:
# str

# %%
x ,y,z = 10, 20 ,30

# %%
x
# Out:
# 10

# %%
y
# Out:
# 20

# %%
z
# Out:
# 30

# %%
x, y,z = 10,20
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-1c576e1d8898> in <module>
# ----> 1 x, y,z = 10,20
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
x = y = z = 10

# %%
x
# Out:
# 10

# %%
y
# Out:
# 10

# %%
z
# Out:
# 10

# %%
x ,y = 10, 20

# %%
x,y = y, x

# %%
x
# Out:
# 20

# %%
del x  ### 변수 삭제
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-6471c246a1cb> in <module>
# ----> 1 del x  ### 변수 삭제
#
# NameError: name 'x' is not defined

# %%
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-6fcf9dfbd479> in <module>
# ----> 1 x
#
# NameError: name 'x' is not defined

# %%
x = None

# %%
x

# %%
print(type(x))
# Out:
# <class 'NoneType'>

# %%
a = 10
b = 20 
c = a+b

# %%
c
# Out:
# 30

# %%
a  = 10

# %%
a + 20
# Out:
# 30

# %%
a
# Out:
# 10

# %%
a = 10

# %%
a = 10 +a

# %%
del a

# %%
a = 10
a += 20

# %%
a
# Out:
# 30

# %%
d += 10
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-b200713d1385> in <module>
# ----> 1 d += 10
#
# NameError: name 'd' is not defined

# %%
x = -10

# %%
+x
# Out:
# -10

# %%
-x
# Out:
# 10
