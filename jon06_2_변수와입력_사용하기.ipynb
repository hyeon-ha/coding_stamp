# %%
input()
# Out:
# Hellow, world!
# 'Hellow, world!'

# %% [markdown]
# 변수 : 프로그램에서 자료를 저장할 수 있는 이름이 주어진 기억장소

# %%
x = input('문자열을 입력하세요: ' )
# Out:
# 문자열을 입력하세요: ㅇ

# %%
x
# Out:
# 'ㅇ'

# %%
a = input('첫번째 숫자를 입력하세요')
b = input('두번째 숫자를 입력하세요')
# Out:
# 첫번째 숫자를 입력하세요23
# 두번째 숫자를 입력하세요34

# %%
print(a+b)
# Out:
# 2334

# %% [markdown]
# input()으로 받는 값은 항상 문자열이다

# %%
a = int(input('첫 번째 숫자를 입력하세요:'))
b = int(input('두 번째 숫자를 입력하세요:'))

print(a+b)
# Out:
# 첫 번째 숫자를 입력하세요:23
# 두 번째 숫자를 입력하세요:34
# 57

# %%
a , b = input('문자열 두 개를 입력하세요:').split()
print(a)
print(b)
# Out:
# 문자열 두 개를 입력하세요:H d
# H
# d

# %%
a , b = input('숫자 두개를 입력하세요').split()

print(a+b)
# Out:
# 숫자 두개를 입력하세요2 3
# 23

# %%
a, b = input('숫자 두개를 입력하세요 : ').split()
a = int(a)
b = int(b)
# Out:
# 숫자 두개를 입력하세요 : 2 3

# %%
print(a+b)
# Out:
# 5

# %%
a , b = input('숫자 두개를입력하세요').split()
# Out:
# 숫자 두개를입력하세요34 23

# %%
print(int(a)+int(b))
# Out:
# 57

# %%
a, b  = map(int, input('숫자 두 개를 입력하세요 :').split())
# Out:
# 숫자 두 개를 입력하세요 :23  533

# %%
print(a + b)
# Out:
# 556

# %%
c ,d = map(float,input("숫자 두개를 입력하세요").split())
# Out:
# 숫자 두개를 입력하세요23 42

# %%
c+d
# Out:
# 65.0

# %%
a ,b, c = map(int, input( '숫자 3개를 입력하세요').split())
# Out:
# 숫자 3개를 입력하세요 2 3 4

# %%
print(a + b + c)
# Out:
# 9
